# %% [markdown]
# # Analyze customer data from Austin, TX.
#
# In this lab, we will analyze various features of customer energy usage data from the Pecan Street dataset. The dataset we aim to explore is for the month of January 2017 from various customers in Austin, TX.
#
# Distinguish which houses have rooftop photovoltaic (PV) panels and which ones do not. For the houses that do not have PV panels, try to predict how much money they would save, given Austin's retail energy rates.
#
# Given the temperature profile, can you predict which houses have AC?

# %%
# Start with customary imports.

import tensorflow as tf
import numpy as np
import pandas as pd
import random
import datetime
import math
from sklearn.model_selection import train_test_split
from sklearn import preprocessing, linear_model
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt

# %% [markdown]
# ## Understand and parse the dataset
#
# There are two csv files that we will utilize in this lab:
# 1. 'dataport-metadata.csv': It contains the details of what data is available from each house in the entire Pecan Street dataset.
# 2. 'July2017.csv': It contains the energy data from houses in Austin for the month of July.
#
# ### Parse the metadata file.
#
# Only consider customers from Austin, TX for which electricity usage data is present.

# %%
# Load the 'metadata' file that contains information about individual houses into a pandas dataframe.
dfCityCustomers = pd.read_csv("dataport-metadata.csv", index_col=0)

# Only consider the houses that are in Austin and have power consumption data.
dfCityCustomers = dfCityCustomers.loc[(dfCityCustomers['city'] == 'Austin') & (dfCityCustomers['use'] == 'yes')]

# Restrict attention to useful columns.
dfCityCustomers = dfCityCustomers[['date_enrolled', 'date_withdrawn', 
                                   'building_type', 'total_square_footage', 'first_floor_square_footage',
                                   'pv', 'air1', 'air2', 'air3', 'airwindowunit1',
                                   'gen', 'use', 'grid']]

# Replace binary data with zeros and ones.
binaryColumns = ['pv', 'air1', 'air2', 'air3', 'airwindowunit1', 'gen', 'use', 'grid']
for bColumn in binaryColumns:
    dfCityCustomers[bColumn] = dfCityCustomers[bColumn].map({'yes' : 1}).fillna(0)

start_day = datetime.datetime.strptime('2017-07-01', '%Y-%m-%d').date()
    
dfCityCustomers['date_enrolled'] = [datetime.datetime.strptime(x, "%Y-%m-%d") 
                                    for x in dfCityCustomers['date_enrolled']]

dfCityCustomers = dfCityCustomers.loc[(dfCityCustomers['date_enrolled'] <= '2017-07-01')]
print("Parsed the metadata file successfully.")
# Out:
# Parsed the metadata file successfully.

# %% [markdown]
# ### Parse the energy usage data.
#
# Here, we shall clean the data.
#
# 1. The data downloaded from dataport.cloud has a mislabeled colmn. Correct that.
# 2. Split the 'localhour' field into two fiels: actual date and an hour of day.
# 3. Only choose data from households that are 'Single-Family Homes'.
# 4. Make sure there is data from 31 days.
# 5. Ensure that the metadata includes the square footage for the entire home and its first floor.
#
# Finally, create a pandas dataframe where indices are house id's.

# %%
# Load the data from Jan 2017 from houses in Texas.
dfData = pd.read_csv("July2017.csv")

# Cleanup item 1. Alter the column names because there is an error in the downloaded data. The column names
# 'dataid' and 'localhour' are switched in the .csv file. Correct it. 
# Cleanup item 2. Split the hour and the day in the field 'localhour' and convert the date to an 
# actual datetime object.

dfData.columns = [x.lstrip() for x in dfData.columns]
dfData = dfData[['dataid', 'localhour', 'use', 'grid', 'gen', 'air1', 'air2', 'air3', 'airwindowunit1']]
dfData.columns = ['date', 'dataid', 'use', 'grid', 'gen', 'air1', 'air2', 'air3', 'airwindowunit1']

dfData['hour'] = [datetime.datetime.strptime(x[:-3], "%Y-%m-%d %H:%M:%S").hour for x in dfData['date']]
dfData['date'] = [datetime.datetime.strptime(x[:-3], "%Y-%m-%d %H:%M:%S").date() for x in dfData['date']]

# Create a dataframe where indices are house id's.
dfData_houses = pd.DataFrame(columns=['ac', 'pv', 'area', 'area_floor', 'data'])

for house_id in dfData['dataid'].unique():
    
    # Make sure that each house with consumption data is also in metadata.
    if house_id in dfCityCustomers.index.values:
        dfData_one_house = dfData.loc[dfData['dataid'] == house_id]

        # Cleanup item 3, 4, 5.
        if ((len(dfData_one_house) >= 24 * 31) & 
        (np.sum(dfData_one_house['use'].values) != 0) & 
        (dfCityCustomers.loc[house_id, 'building_type'] == 'Single-Family Home') & 
        (np.isnan(dfCityCustomers.loc[house_id, 'total_square_footage']) == False) & 
        (np.isnan(dfCityCustomers.loc[house_id, 'first_floor_square_footage']) == False)):
            
            # Create a pandas dataframe with house id's as indices and has the following items: 
            # 1. Binary status: "ac", "pv".
            # 2. Total square footrage, and the square footage of the first floor.
            
            is_ac_in_house =  (dfCityCustomers.loc[house_id, 'air1'] 
                               or dfCityCustomers.loc[house_id, 'air2']
                               or dfCityCustomers.loc[house_id, 'air3']
                               or dfCityCustomers.loc[house_id, 'airwindowunit1']
                              )
            
            dfData_houses.loc[house_id] = [is_ac_in_house, 
                                           dfCityCustomers.loc[house_id, 'pv'],
                                           dfCityCustomers.loc[house_id, 'total_square_footage'],
                                           dfCityCustomers.loc[house_id, 'first_floor_square_footage'],
                                           dfData_one_house
                                          ]

# Define a function that retrieves the hourly energy profile from the column in "field" from a
# specific house and day. The day is measured as number of days since the start date of Jan 1, 2017.

def energy_day(house_id, day, field): 
    date_day = start_day + datetime.timedelta(days=day)
    dfData_house = dfData_houses.loc[house_id, 'data']
    return dfData_house.loc[dfData_house['date'] == date_day].sort_values(by=['hour'])[field].values

# Define a function that retrieves the aggregate energy consumed (or produced) as detailed in the column 
# named "field" from a specific house over all days.

def total_energy_all_days(house_id, field): 
    total_energy = 0
    for day in range(31):
        total_energy += np.sum(energy_day(house_id, day, field))
    return total_energy


# Cleanup item 4 continued: Delete data from houses where the date and hour do not perfectly 
# align with the 31 days in July, and hours being from 0 to 23.
house_ids_to_delete = []
for house_id in dfData_houses.index.values:
    for day in range(31):
        if len(energy_day(house_id, day, 'grid')) != 24:
            house_ids_to_delete.append(house_id)
            continue

dfData_houses.drop(house_ids_to_delete, inplace=True)

print("Data loaded and parsed successfully from %d single-family homes." % (len(dfData_houses)))

del dfData , dfCityCustomers
# Out:
# Data loaded and parsed successfully from 222 single-family homes.

# %% [markdown]
# ## Distinguish houses with rooftop solar panels from daily energy usage profile.
#
# Take data of energy drawn from the grid for 10 days and do logistic regression.
#
# ### Q1. Explain Logistic regression. (10 points)
#
# #### my training data is train X and trainY. My model takes trainX as inputs and predicts trainY.  For an input vector x the output y is calculated as y=logistic(z) and z = W.T*x + b. [ logistic(z)=1/(1+exp(-z)) ] W consists of the weights and b is the bias for that layer.  It does this over a number of epochs adjusting W and b with the aim of minimizing the cross entropy between the predicted class and the target class to predict Y better every adjustment/epoch.  Then you use the trained model with set weights and bias to predict testY using testX as the input.

# %%
print("Number of houses with PV panels = %d" % (len(dfData_houses.loc[dfData_houses['pv'] == 1])) )
print("Number of houses without PV panels = %d" % (len(dfData_houses.loc[dfData_houses['pv'] == 0])) )

XX = []
YY = []

days_data = random.sample(range(31), 10)

for house_id in dfData_houses.index.values:
    XX.append(np.ravel([energy_day(house_id, day, 'grid') for day in days_data]))
    YY.append(dfData_houses.loc[house_id, 'pv'])

YY = np.reshape(YY, (-1, 1))

train_X, test_X, train_Y, test_Y = train_test_split(XX, YY, test_size=.2, shuffle=True)

train_X = tf.dtypes.cast(train_X, tf.float32)
test_X = tf.dtypes.cast(test_X, tf.float32)
train_Y = tf.dtypes.cast(train_Y, tf.float32)
test_Y = tf.dtypes.cast(test_Y, tf.float32)

del XX, YY
# Out:
# Number of houses with PV panels = 146
# Number of houses without PV panels = 76

# %% [markdown]
# ### Q2. Design the neural network. In the next cell, fill in the missing pieces. (30 points)

# %%
n_inputs = np.shape(train_X)[1]
n_outputs = np.shape(train_Y)[1]

weight = tf.Variable(tf.random.truncated_normal(shape=[n_inputs, n_outputs]))
bias = tf.Variable(tf.random.truncated_normal(shape=[n_outputs]))

@tf.function
def neuralNetworkModel(X):
    global weight, bias
    # enter code here (hint: tf.nn.sigmoid may be useful)
    Z=tf.nn.sigmoid(tf.matmul(X, weight) + bias)
    return Z

loss_fn = tf.losses.BinaryCrossentropy()
# Enter code here (hint: tf.losses.BinaryCrossentropy may be useful)
optimizer = tf.optimizers.Adagrad(learning_rate=0.01)
# Enter code here (hint: the learning rate may need to be small)

# Define number of epochs
nEpoch = 1000

# Define the training scheme
def train(model, x_set, y_set):
    trainable_variables=[weight, bias]
    for epoch in range(nEpoch):
        # Fit the data and compute the gradients
        with tf.GradientTape() as tape:
            prediction = model(x_set)
            loss = loss_fn(y_true=y_set, y_pred=prediction)
            
            # Print update
            lossEpoch = loss.numpy()
            print("Epoch: %d, Loss: = %1.1f" % (epoch + 1, lossEpoch))
            
            # Optimize the weights
            gradients = tape.gradient(loss, trainable_variables)
            optimizer.apply_gradients(zip(gradients, trainable_variables))

# Train the model
print ("Start neural network training.")
train(neuralNetworkModel, train_X, train_Y)

test_prediction = tf.math.round(neuralNetworkModel(test_X))
test_accuracy = tf.math.reduce_mean(tf.dtypes.cast(tf.math.equal(test_Y, test_prediction), tf.float32))
print("Accuracy of logistic regression on test data = %.2f percent." % (test_accuracy * 100))
# Out:
# Start neural network training.
# Epoch: 1, Loss: = 5.6
# Epoch: 2, Loss: = 5.6
# Epoch: 3, Loss: = 5.6
# Epoch: 4, Loss: = 5.5
# Epoch: 5, Loss: = 5.5
# Epoch: 6, Loss: = 5.5
# Epoch: 7, Loss: = 5.5
# Epoch: 8, Loss: = 5.5
# Epoch: 9, Loss: = 5.4
# Epoch: 10, Loss: = 5.4
# Epoch: 11, Loss: = 5.4
# Epoch: 12, Loss: = 5.4
# Epoch: 13, Loss: = 5.3
# Epoch: 14, Loss: = 5.3
# Epoch: 15, Loss: = 5.3
# Epoch: 16, Loss: = 5.2
# Epoch: 17, Loss: = 5.2
# Epoch: 18, Loss: = 5.1
# Epoch: 19, Loss: = 5.1
# Epoch: 20, Loss: = 5.0
# Epoch: 21, Loss: = 4.9
# Epoch: 22, Loss: = 4.9
# Epoch: 23, Loss: = 4.8
# Epoch: 24, Loss: = 4.7
# Epoch: 25, Loss: = 4.6
# Epoch: 26, Loss: = 4.5
# Epoch: 27, Loss: = 4.3
# Epoch: 28, Loss: = 4.0
# Epoch: 29, Loss: = 3.8
# Epoch: 30, Loss: = 3.6
# Epoch: 31, Loss: = 3.3
# Epoch: 32, Loss: = 3.0
# Epoch: 33, Loss: = 2.7
# Epoch: 34, Loss: = 2.3
# Epoch: 35, Loss: = 2.1
# Epoch: 36, Loss: = 1.9
# Epoch: 37, Loss: = 1.8
# Epoch: 38, Loss: = 1.6
# Epoch: 39, Loss: = 1.5
# Epoch: 40, Loss: = 1.5
# Epoch: 41, Loss: = 1.4
# Epoch: 42, Loss: = 1.4
# Epoch: 43, Loss: = 1.3
# Epoch: 44, Loss: = 1.3
# Epoch: 45, Loss: = 1.3
# Epoch: 46, Loss: = 1.3
# Epoch: 47, Loss: = 1.2
# Epoch: 48, Loss: = 1.2
# Epoch: 49, Loss: = 1.2
# Epoch: 50, Loss: = 1.2
# Epoch: 51, Loss: = 1.2
# Epoch: 52, Loss: = 1.1
# Epoch: 53, Loss: = 1.1
# Epoch: 54, Loss: = 1.1
# Epoch: 55, Loss: = 1.1
# Epoch: 56, Loss: = 1.1
# Epoch: 57, Loss: = 1.1
# Epoch: 58, Loss: = 1.1
# Epoch: 59, Loss: = 1.1
# Epoch: 60, Loss: = 1.0
# Epoch: 61, Loss: = 1.0
# Epoch: 62, Loss: = 1.0
# Epoch: 63, Loss: = 1.0
# Epoch: 64, Loss: = 1.0
# Epoch: 65, Loss: = 1.0
# Epoch: 66, Loss: = 1.0
# Epoch: 67, Loss: = 1.0
# Epoch: 68, Loss: = 1.0
# Epoch: 69, Loss: = 1.0
# Epoch: 70, Loss: = 1.0
# Epoch: 71, Loss: = 1.0
# Epoch: 72, Loss: = 1.0
# Epoch: 73, Loss: = 0.9
# Epoch: 74, Loss: = 0.9
# Epoch: 75, Loss: = 0.9
# Epoch: 76, Loss: = 0.9
# Epoch: 77, Loss: = 0.9
# Epoch: 78, Loss: = 0.9
# Epoch: 79, Loss: = 0.9
# Epoch: 80, Loss: = 0.9
# Epoch: 81, Loss: = 0.9
# Epoch: 82, Loss: = 0.9
# Epoch: 83, Loss: = 0.9
# Epoch: 84, Loss: = 0.9
# Epoch: 85, Loss: = 0.9
# Epoch: 86, Loss: = 0.9
# Epoch: 87, Loss: = 0.9
# Epoch: 88, Loss: = 0.9
# Epoch: 89, Loss: = 0.9
# Epoch: 90, Loss: = 0.9
# Epoch: 91, Loss: = 0.9
# Epoch: 92, Loss: = 0.9
# Epoch: 93, Loss: = 0.9
# Epoch: 94, Loss: = 0.9
# Epoch: 95, Loss: = 0.9
# Epoch: 96, Loss: = 0.9
# Epoch: 97, Loss: = 0.9
# Epoch: 98, Loss: = 0.9
# Epoch: 99, Loss: = 0.9
# Epoch: 100, Loss: = 0.9
# Epoch: 101, Loss: = 0.9
# Epoch: 102, Loss: = 0.9
# Epoch: 103, Loss: = 0.9
# Epoch: 104, Loss: = 0.9
# Epoch: 105, Loss: = 0.9
# Epoch: 106, Loss: = 0.9
# Epoch: 107, Loss: = 0.9
# Epoch: 108, Loss: = 0.9
# Epoch: 109, Loss: = 0.9
# Epoch: 110, Loss: = 0.9
# Epoch: 111, Loss: = 0.9
# Epoch: 112, Loss: = 0.9
# Epoch: 113, Loss: = 0.9
# Epoch: 114, Loss: = 0.8
# Epoch: 115, Loss: = 0.8
# Epoch: 116, Loss: = 0.8
# Epoch: 117, Loss: = 0.8
# Epoch: 118, Loss: = 0.8
# Epoch: 119, Loss: = 0.8
# Epoch: 120, Loss: = 0.8
# Epoch: 121, Loss: = 0.8
# Epoch: 122, Loss: = 0.8
# Epoch: 123, Loss: = 0.8
# Epoch: 124, Loss: = 0.8
# Epoch: 125, Loss: = 0.8
# Epoch: 126, Loss: = 0.8
# Epoch: 127, Loss: = 0.8
# Epoch: 128, Loss: = 0.8
# Epoch: 129, Loss: = 0.8
# Epoch: 130, Loss: = 0.8
# Epoch: 131, Loss: = 0.8
# Epoch: 132, Loss: = 0.8
# Epoch: 133, Loss: = 0.8
# Epoch: 134, Loss: = 0.8
# Epoch: 135, Loss: = 0.8
# Epoch: 136, Loss: = 0.8
# Epoch: 137, Loss: = 0.8
# Epoch: 138, Loss: = 0.8
# Epoch: 139, Loss: = 0.8
# Epoch: 140, Loss: = 0.8
# Epoch: 141, Loss: = 0.8
# Epoch: 142, Loss: = 0.8
# Epoch: 143, Loss: = 0.8
# Epoch: 144, Loss: = 0.8
# Epoch: 145, Loss: = 0.8
# Epoch: 146, Loss: = 0.8
# Epoch: 147, Loss: = 0.8
# Epoch: 148, Loss: = 0.8
# Epoch: 149, Loss: = 0.8
# Epoch: 150, Loss: = 0.8
# Epoch: 151, Loss: = 0.8
# Epoch: 152, Loss: = 0.8
# Epoch: 153, Loss: = 0.8
# Epoch: 154, Loss: = 0.8
# Epoch: 155, Loss: = 0.8
# Epoch: 156, Loss: = 0.8
# Epoch: 157, Loss: = 0.8
# Epoch: 158, Loss: = 0.8
# Epoch: 159, Loss: = 0.8
# Epoch: 160, Loss: = 0.8
# Epoch: 161, Loss: = 0.8
# Epoch: 162, Loss: = 0.8
# Epoch: 163, Loss: = 0.8
# Epoch: 164, Loss: = 0.8
# Epoch: 165, Loss: = 0.8
# Epoch: 166, Loss: = 0.8
# Epoch: 167, Loss: = 0.7
# Epoch: 168, Loss: = 0.7
# Epoch: 169, Loss: = 0.7
# Epoch: 170, Loss: = 0.7
# Epoch: 171, Loss: = 0.7
# Epoch: 172, Loss: = 0.7
# Epoch: 173, Loss: = 0.7
# Epoch: 174, Loss: = 0.7
# Epoch: 175, Loss: = 0.7
# Epoch: 176, Loss: = 0.7
# Epoch: 177, Loss: = 0.7
# Epoch: 178, Loss: = 0.7
# Epoch: 179, Loss: = 0.7
# Epoch: 180, Loss: = 0.7
# Epoch: 181, Loss: = 0.7
# Epoch: 182, Loss: = 0.7
# Epoch: 183, Loss: = 0.7
# Epoch: 184, Loss: = 0.7
# Epoch: 185, Loss: = 0.7
# Epoch: 186, Loss: = 0.7
# Epoch: 187, Loss: = 0.7
# Epoch: 188, Loss: = 0.7
# Epoch: 189, Loss: = 0.7
# Epoch: 190, Loss: = 0.7
# Epoch: 191, Loss: = 0.7
# Epoch: 192, Loss: = 0.7
# Epoch: 193, Loss: = 0.7
# Epoch: 194, Loss: = 0.7
# Epoch: 195, Loss: = 0.7
# Epoch: 196, Loss: = 0.7
# Epoch: 197, Loss: = 0.7
# Epoch: 198, Loss: = 0.7
# Epoch: 199, Loss: = 0.7
# Epoch: 200, Loss: = 0.7
# Epoch: 201, Loss: = 0.7
# Epoch: 202, Loss: = 0.7
# Epoch: 203, Loss: = 0.7
# Epoch: 204, Loss: = 0.7
# Epoch: 205, Loss: = 0.7
# Epoch: 206, Loss: = 0.7
# Epoch: 207, Loss: = 0.7
# Epoch: 208, Loss: = 0.7
# Epoch: 209, Loss: = 0.7
# Epoch: 210, Loss: = 0.7
# Epoch: 211, Loss: = 0.7
# Epoch: 212, Loss: = 0.7
# Epoch: 213, Loss: = 0.7
# Epoch: 214, Loss: = 0.7
# Epoch: 215, Loss: = 0.7
# Epoch: 216, Loss: = 0.7
# Epoch: 217, Loss: = 0.7
# Epoch: 218, Loss: = 0.7
# Epoch: 219, Loss: = 0.7
# Epoch: 220, Loss: = 0.7
# Epoch: 221, Loss: = 0.7
# Epoch: 222, Loss: = 0.7
# Epoch: 223, Loss: = 0.7
# Epoch: 224, Loss: = 0.7
# Epoch: 225, Loss: = 0.7
# Epoch: 226, Loss: = 0.7
# Epoch: 227, Loss: = 0.7
# Epoch: 228, Loss: = 0.7
# Epoch: 229, Loss: = 0.7
# Epoch: 230, Loss: = 0.7
# Epoch: 231, Loss: = 0.7
# Epoch: 232, Loss: = 0.7
# Epoch: 233, Loss: = 0.7
# Epoch: 234, Loss: = 0.7
# Epoch: 235, Loss: = 0.7
# Epoch: 236, Loss: = 0.6
# Epoch: 237, Loss: = 0.6
# Epoch: 238, Loss: = 0.6
# Epoch: 239, Loss: = 0.6
# Epoch: 240, Loss: = 0.6
# Epoch: 241, Loss: = 0.6
# Epoch: 242, Loss: = 0.6
# Epoch: 243, Loss: = 0.6
# Epoch: 244, Loss: = 0.6
# Epoch: 245, Loss: = 0.6
# Epoch: 246, Loss: = 0.6
# Epoch: 247, Loss: = 0.6
# Epoch: 248, Loss: = 0.6
# Epoch: 249, Loss: = 0.6
# Epoch: 250, Loss: = 0.6
# Epoch: 251, Loss: = 0.6
# Epoch: 252, Loss: = 0.6
# Epoch: 253, Loss: = 0.6
# Epoch: 254, Loss: = 0.6
# Epoch: 255, Loss: = 0.6
# Epoch: 256, Loss: = 0.6
# Epoch: 257, Loss: = 0.6
# Epoch: 258, Loss: = 0.6
# Epoch: 259, Loss: = 0.6
# Epoch: 260, Loss: = 0.6
# Epoch: 261, Loss: = 0.6
# Epoch: 262, Loss: = 0.6
# Epoch: 263, Loss: = 0.6
# Epoch: 264, Loss: = 0.6
# Epoch: 265, Loss: = 0.6
# Epoch: 266, Loss: = 0.6
# Epoch: 267, Loss: = 0.6
# Epoch: 268, Loss: = 0.6
# Epoch: 269, Loss: = 0.6
# Epoch: 270, Loss: = 0.6
# Epoch: 271, Loss: = 0.6
# Epoch: 272, Loss: = 0.6
# Epoch: 273, Loss: = 0.6
# Epoch: 274, Loss: = 0.6
# Epoch: 275, Loss: = 0.6
# Epoch: 276, Loss: = 0.6
# Epoch: 277, Loss: = 0.6
# Epoch: 278, Loss: = 0.6
# Epoch: 279, Loss: = 0.6
# Epoch: 280, Loss: = 0.6
# Epoch: 281, Loss: = 0.6
# Epoch: 282, Loss: = 0.6
# Epoch: 283, Loss: = 0.6
# Epoch: 284, Loss: = 0.6
# Epoch: 285, Loss: = 0.6
# Epoch: 286, Loss: = 0.6
# Epoch: 287, Loss: = 0.6
# Epoch: 288, Loss: = 0.6
# Epoch: 289, Loss: = 0.6
# Epoch: 290, Loss: = 0.6
# Epoch: 291, Loss: = 0.6
# Epoch: 292, Loss: = 0.6
# Epoch: 293, Loss: = 0.6
# Epoch: 294, Loss: = 0.6
# Epoch: 295, Loss: = 0.6
# Epoch: 296, Loss: = 0.6
# Epoch: 297, Loss: = 0.6
# Epoch: 298, Loss: = 0.6
# Epoch: 299, Loss: = 0.6
# Epoch: 300, Loss: = 0.6
# Epoch: 301, Loss: = 0.6
# Epoch: 302, Loss: = 0.6
# Epoch: 303, Loss: = 0.6
# Epoch: 304, Loss: = 0.6
# Epoch: 305, Loss: = 0.6
# Epoch: 306, Loss: = 0.6
# Epoch: 307, Loss: = 0.6
# Epoch: 308, Loss: = 0.6
# Epoch: 309, Loss: = 0.6
# Epoch: 310, Loss: = 0.6
# Epoch: 311, Loss: = 0.6
# Epoch: 312, Loss: = 0.6
# Epoch: 313, Loss: = 0.6
# Epoch: 314, Loss: = 0.6
# Epoch: 315, Loss: = 0.6
# Epoch: 316, Loss: = 0.6
# Epoch: 317, Loss: = 0.6
# Epoch: 318, Loss: = 0.6
# Epoch: 319, Loss: = 0.6
# Epoch: 320, Loss: = 0.6
# Epoch: 321, Loss: = 0.6
# Epoch: 322, Loss: = 0.6
# Epoch: 323, Loss: = 0.6
# Epoch: 324, Loss: = 0.6
# Epoch: 325, Loss: = 0.6
# Epoch: 326, Loss: = 0.6
# Epoch: 327, Loss: = 0.6
# Epoch: 328, Loss: = 0.6
# Epoch: 329, Loss: = 0.6
# Epoch: 330, Loss: = 0.6
# Epoch: 331, Loss: = 0.6
# Epoch: 332, Loss: = 0.6
# Epoch: 333, Loss: = 0.6
# Epoch: 334, Loss: = 0.6
# Epoch: 335, Loss: = 0.6
# Epoch: 336, Loss: = 0.6
# Epoch: 337, Loss: = 0.6
# Epoch: 338, Loss: = 0.6
# Epoch: 339, Loss: = 0.6
# Epoch: 340, Loss: = 0.6
# Epoch: 341, Loss: = 0.6
# Epoch: 342, Loss: = 0.6
# Epoch: 343, Loss: = 0.6
# Epoch: 344, Loss: = 0.5
# Epoch: 345, Loss: = 0.5
# Epoch: 346, Loss: = 0.5
# Epoch: 347, Loss: = 0.5
# Epoch: 348, Loss: = 0.5
# Epoch: 349, Loss: = 0.5
# Epoch: 350, Loss: = 0.5
# Epoch: 351, Loss: = 0.5
# Epoch: 352, Loss: = 0.5
# Epoch: 353, Loss: = 0.5
# Epoch: 354, Loss: = 0.5
# Epoch: 355, Loss: = 0.5
# Epoch: 356, Loss: = 0.5
# Epoch: 357, Loss: = 0.5
# Epoch: 358, Loss: = 0.5
# Epoch: 359, Loss: = 0.5
# Epoch: 360, Loss: = 0.5
# Epoch: 361, Loss: = 0.5
# Epoch: 362, Loss: = 0.5
# Epoch: 363, Loss: = 0.5
# Epoch: 364, Loss: = 0.5
# Epoch: 365, Loss: = 0.5
# Epoch: 366, Loss: = 0.5
# Epoch: 367, Loss: = 0.5
# Epoch: 368, Loss: = 0.5
# Epoch: 369, Loss: = 0.5
# Epoch: 370, Loss: = 0.5
# Epoch: 371, Loss: = 0.5
# Epoch: 372, Loss: = 0.5
# Epoch: 373, Loss: = 0.5
# Epoch: 374, Loss: = 0.5
# Epoch: 375, Loss: = 0.5
# Epoch: 376, Loss: = 0.5
# Epoch: 377, Loss: = 0.5
# Epoch: 378, Loss: = 0.5
# Epoch: 379, Loss: = 0.5
# Epoch: 380, Loss: = 0.5
# Epoch: 381, Loss: = 0.5
# Epoch: 382, Loss: = 0.5
# Epoch: 383, Loss: = 0.5
# Epoch: 384, Loss: = 0.5
# Epoch: 385, Loss: = 0.5
# Epoch: 386, Loss: = 0.5
# Epoch: 387, Loss: = 0.5
# Epoch: 388, Loss: = 0.5
# Epoch: 389, Loss: = 0.5
# Epoch: 390, Loss: = 0.5
# Epoch: 391, Loss: = 0.5
# Epoch: 392, Loss: = 0.5
# Epoch: 393, Loss: = 0.5
# Epoch: 394, Loss: = 0.5
# Epoch: 395, Loss: = 0.5
# Epoch: 396, Loss: = 0.5
# Epoch: 397, Loss: = 0.5
# Epoch: 398, Loss: = 0.5
# Epoch: 399, Loss: = 0.5
# Epoch: 400, Loss: = 0.5
# Epoch: 401, Loss: = 0.5
# Epoch: 402, Loss: = 0.5
# Epoch: 403, Loss: = 0.5
# Epoch: 404, Loss: = 0.5
# Epoch: 405, Loss: = 0.5
# Epoch: 406, Loss: = 0.5
# Epoch: 407, Loss: = 0.5
# Epoch: 408, Loss: = 0.5
# Epoch: 409, Loss: = 0.5
# Epoch: 410, Loss: = 0.5
# Epoch: 411, Loss: = 0.5
# Epoch: 412, Loss: = 0.5
# Epoch: 413, Loss: = 0.5
# Epoch: 414, Loss: = 0.5
# Epoch: 415, Loss: = 0.5
# Epoch: 416, Loss: = 0.5
# Epoch: 417, Loss: = 0.5
# Epoch: 418, Loss: = 0.5
# Epoch: 419, Loss: = 0.5
# Epoch: 420, Loss: = 0.5
# Epoch: 421, Loss: = 0.5
# Epoch: 422, Loss: = 0.5
# Epoch: 423, Loss: = 0.5
# Epoch: 424, Loss: = 0.5
# Epoch: 425, Loss: = 0.5
# Epoch: 426, Loss: = 0.5
# Epoch: 427, Loss: = 0.5
# Epoch: 428, Loss: = 0.5
# Epoch: 429, Loss: = 0.5
# Epoch: 430, Loss: = 0.5
# Epoch: 431, Loss: = 0.5
# Epoch: 432, Loss: = 0.5
# Epoch: 433, Loss: = 0.5
# Epoch: 434, Loss: = 0.5
# Epoch: 435, Loss: = 0.5
# Epoch: 436, Loss: = 0.5
# Epoch: 437, Loss: = 0.5
# Epoch: 438, Loss: = 0.5
# Epoch: 439, Loss: = 0.5
# Epoch: 440, Loss: = 0.5
# Epoch: 441, Loss: = 0.5
# Epoch: 442, Loss: = 0.5
# Epoch: 443, Loss: = 0.5
# Epoch: 444, Loss: = 0.5
# Epoch: 445, Loss: = 0.5
# Epoch: 446, Loss: = 0.5
# Epoch: 447, Loss: = 0.5
# Epoch: 448, Loss: = 0.5
# Epoch: 449, Loss: = 0.5
# Epoch: 450, Loss: = 0.5
# Epoch: 451, Loss: = 0.5
# Epoch: 452, Loss: = 0.5
# Epoch: 453, Loss: = 0.5
# Epoch: 454, Loss: = 0.5
# Epoch: 455, Loss: = 0.5
# Epoch: 456, Loss: = 0.5
# Epoch: 457, Loss: = 0.5
# Epoch: 458, Loss: = 0.5
# Epoch: 459, Loss: = 0.5
# Epoch: 460, Loss: = 0.5
# Epoch: 461, Loss: = 0.5
# Epoch: 462, Loss: = 0.5
# Epoch: 463, Loss: = 0.5
# Epoch: 464, Loss: = 0.5
# Epoch: 465, Loss: = 0.5
# Epoch: 466, Loss: = 0.5
# Epoch: 467, Loss: = 0.5
# Epoch: 468, Loss: = 0.5
# Epoch: 469, Loss: = 0.5
# Epoch: 470, Loss: = 0.5
# Epoch: 471, Loss: = 0.5
# Epoch: 472, Loss: = 0.5
# Epoch: 473, Loss: = 0.5
# Epoch: 474, Loss: = 0.5
# Epoch: 475, Loss: = 0.5
# Epoch: 476, Loss: = 0.5
# Epoch: 477, Loss: = 0.5
# Epoch: 478, Loss: = 0.5
# Epoch: 479, Loss: = 0.5
# Epoch: 480, Loss: = 0.5
# Epoch: 481, Loss: = 0.5
# Epoch: 482, Loss: = 0.5
# Epoch: 483, Loss: = 0.5
# Epoch: 484, Loss: = 0.5
# Epoch: 485, Loss: = 0.5
# Epoch: 486, Loss: = 0.5
# Epoch: 487, Loss: = 0.5
# Epoch: 488, Loss: = 0.5
# Epoch: 489, Loss: = 0.5
# Epoch: 490, Loss: = 0.5
# Epoch: 491, Loss: = 0.5
# Epoch: 492, Loss: = 0.5
# Epoch: 493, Loss: = 0.5
# Epoch: 494, Loss: = 0.5
# Epoch: 495, Loss: = 0.5
# Epoch: 496, Loss: = 0.5
# Epoch: 497, Loss: = 0.5
# Epoch: 498, Loss: = 0.5
# Epoch: 499, Loss: = 0.5
# Epoch: 500, Loss: = 0.5
# Epoch: 501, Loss: = 0.5
# Epoch: 502, Loss: = 0.5
# Epoch: 503, Loss: = 0.5
# Epoch: 504, Loss: = 0.5
# Epoch: 505, Loss: = 0.5
# Epoch: 506, Loss: = 0.5
# Epoch: 507, Loss: = 0.5
# Epoch: 508, Loss: = 0.5
# Epoch: 509, Loss: = 0.5
# Epoch: 510, Loss: = 0.4
# Epoch: 511, Loss: = 0.4
# Epoch: 512, Loss: = 0.4
# Epoch: 513, Loss: = 0.4
# Epoch: 514, Loss: = 0.4
# Epoch: 515, Loss: = 0.4
# Epoch: 516, Loss: = 0.4
# Epoch: 517, Loss: = 0.4
# Epoch: 518, Loss: = 0.4
# Epoch: 519, Loss: = 0.4
# Epoch: 520, Loss: = 0.4
# Epoch: 521, Loss: = 0.4
# Epoch: 522, Loss: = 0.4
# Epoch: 523, Loss: = 0.4
# Epoch: 524, Loss: = 0.4
# Epoch: 525, Loss: = 0.4
# Epoch: 526, Loss: = 0.4
# Epoch: 527, Loss: = 0.4
# Epoch: 528, Loss: = 0.4
# Epoch: 529, Loss: = 0.4
# Epoch: 530, Loss: = 0.4
# Epoch: 531, Loss: = 0.4
# Epoch: 532, Loss: = 0.4
# Epoch: 533, Loss: = 0.4
# Epoch: 534, Loss: = 0.4
# Epoch: 535, Loss: = 0.4
# Epoch: 536, Loss: = 0.4
# Epoch: 537, Loss: = 0.4
# Epoch: 538, Loss: = 0.4
# Epoch: 539, Loss: = 0.4
# Epoch: 540, Loss: = 0.4
# Epoch: 541, Loss: = 0.4
# Epoch: 542, Loss: = 0.4
# Epoch: 543, Loss: = 0.4
# Epoch: 544, Loss: = 0.4
# Epoch: 545, Loss: = 0.4
# Epoch: 546, Loss: = 0.4
# Epoch: 547, Loss: = 0.4
# Epoch: 548, Loss: = 0.4
# Epoch: 549, Loss: = 0.4
# Epoch: 550, Loss: = 0.4
# Epoch: 551, Loss: = 0.4
# Epoch: 552, Loss: = 0.4
# Epoch: 553, Loss: = 0.4
# Epoch: 554, Loss: = 0.4
# Epoch: 555, Loss: = 0.4
# Epoch: 556, Loss: = 0.4
# Epoch: 557, Loss: = 0.4
# Epoch: 558, Loss: = 0.4
# Epoch: 559, Loss: = 0.4
# Epoch: 560, Loss: = 0.4
# Epoch: 561, Loss: = 0.4
# Epoch: 562, Loss: = 0.4
# Epoch: 563, Loss: = 0.4
# Epoch: 564, Loss: = 0.4
# Epoch: 565, Loss: = 0.4
# Epoch: 566, Loss: = 0.4
# Epoch: 567, Loss: = 0.4
# Epoch: 568, Loss: = 0.4
# Epoch: 569, Loss: = 0.4
# Epoch: 570, Loss: = 0.4
# Epoch: 571, Loss: = 0.4
# Epoch: 572, Loss: = 0.4
# Epoch: 573, Loss: = 0.4
# Epoch: 574, Loss: = 0.4
# Epoch: 575, Loss: = 0.4
# Epoch: 576, Loss: = 0.4
# Epoch: 577, Loss: = 0.4
# Epoch: 578, Loss: = 0.4
# Epoch: 579, Loss: = 0.4
# Epoch: 580, Loss: = 0.4
# Epoch: 581, Loss: = 0.4
# Epoch: 582, Loss: = 0.4
# Epoch: 583, Loss: = 0.4
# Epoch: 584, Loss: = 0.4
# Epoch: 585, Loss: = 0.4
# Epoch: 586, Loss: = 0.4
# Epoch: 587, Loss: = 0.4
# Epoch: 588, Loss: = 0.4
# Epoch: 589, Loss: = 0.4
# Epoch: 590, Loss: = 0.4
# Epoch: 591, Loss: = 0.4
# Epoch: 592, Loss: = 0.4
# Epoch: 593, Loss: = 0.4
# Epoch: 594, Loss: = 0.4
# Epoch: 595, Loss: = 0.4
# Epoch: 596, Loss: = 0.4
# Epoch: 597, Loss: = 0.4
# Epoch: 598, Loss: = 0.4
# Epoch: 599, Loss: = 0.4
# Epoch: 600, Loss: = 0.4
# Epoch: 601, Loss: = 0.4
# Epoch: 602, Loss: = 0.4
# Epoch: 603, Loss: = 0.4
# Epoch: 604, Loss: = 0.4
# Epoch: 605, Loss: = 0.4
# Epoch: 606, Loss: = 0.4
# Epoch: 607, Loss: = 0.4
# Epoch: 608, Loss: = 0.4
# Epoch: 609, Loss: = 0.4
# Epoch: 610, Loss: = 0.4
# Epoch: 611, Loss: = 0.4
# Epoch: 612, Loss: = 0.4
# Epoch: 613, Loss: = 0.4
# Epoch: 614, Loss: = 0.4
# Epoch: 615, Loss: = 0.4
# Epoch: 616, Loss: = 0.4
# Epoch: 617, Loss: = 0.4
# Epoch: 618, Loss: = 0.4
# Epoch: 619, Loss: = 0.4
# Epoch: 620, Loss: = 0.4
# Epoch: 621, Loss: = 0.4
# Epoch: 622, Loss: = 0.4
# Epoch: 623, Loss: = 0.4
# Epoch: 624, Loss: = 0.4
# Epoch: 625, Loss: = 0.4
# Epoch: 626, Loss: = 0.4
# Epoch: 627, Loss: = 0.4
# Epoch: 628, Loss: = 0.4
# Epoch: 629, Loss: = 0.4
# Epoch: 630, Loss: = 0.4
# Epoch: 631, Loss: = 0.4
# Epoch: 632, Loss: = 0.4
# Epoch: 633, Loss: = 0.4
# Epoch: 634, Loss: = 0.4
# Epoch: 635, Loss: = 0.4
# Epoch: 636, Loss: = 0.4
# Epoch: 637, Loss: = 0.4
# Epoch: 638, Loss: = 0.4
# Epoch: 639, Loss: = 0.4
# Epoch: 640, Loss: = 0.4
# Epoch: 641, Loss: = 0.4
# Epoch: 642, Loss: = 0.4
# Epoch: 643, Loss: = 0.4
# Epoch: 644, Loss: = 0.4
# Epoch: 645, Loss: = 0.4
# Epoch: 646, Loss: = 0.4
# Epoch: 647, Loss: = 0.4
# Epoch: 648, Loss: = 0.4
# Epoch: 649, Loss: = 0.4
# Epoch: 650, Loss: = 0.4
# Epoch: 651, Loss: = 0.4
# Epoch: 652, Loss: = 0.4
# Epoch: 653, Loss: = 0.4
# Epoch: 654, Loss: = 0.4
# Epoch: 655, Loss: = 0.4
# Epoch: 656, Loss: = 0.4
# Epoch: 657, Loss: = 0.4
# Epoch: 658, Loss: = 0.4
# Epoch: 659, Loss: = 0.4
# Epoch: 660, Loss: = 0.4
# Epoch: 661, Loss: = 0.4
# Epoch: 662, Loss: = 0.4
# Epoch: 663, Loss: = 0.4
# Epoch: 664, Loss: = 0.4
# Epoch: 665, Loss: = 0.4
# Epoch: 666, Loss: = 0.4
# Epoch: 667, Loss: = 0.4
# Epoch: 668, Loss: = 0.4
# Epoch: 669, Loss: = 0.4
# Epoch: 670, Loss: = 0.4
# Epoch: 671, Loss: = 0.4
# Epoch: 672, Loss: = 0.4
# Epoch: 673, Loss: = 0.4
# Epoch: 674, Loss: = 0.4
# Epoch: 675, Loss: = 0.4
# Epoch: 676, Loss: = 0.4
# Epoch: 677, Loss: = 0.4
# Epoch: 678, Loss: = 0.4
# Epoch: 679, Loss: = 0.4
# Epoch: 680, Loss: = 0.4
# Epoch: 681, Loss: = 0.4
# Epoch: 682, Loss: = 0.4
# Epoch: 683, Loss: = 0.4
# Epoch: 684, Loss: = 0.4
# Epoch: 685, Loss: = 0.4
# Epoch: 686, Loss: = 0.4
# Epoch: 687, Loss: = 0.4
# Epoch: 688, Loss: = 0.4
# Epoch: 689, Loss: = 0.4
# Epoch: 690, Loss: = 0.4
# Epoch: 691, Loss: = 0.4
# Epoch: 692, Loss: = 0.4
# Epoch: 693, Loss: = 0.4
# Epoch: 694, Loss: = 0.4
# Epoch: 695, Loss: = 0.4
# Epoch: 696, Loss: = 0.4
# Epoch: 697, Loss: = 0.4
# Epoch: 698, Loss: = 0.4
# Epoch: 699, Loss: = 0.4
# Epoch: 700, Loss: = 0.4
# Epoch: 701, Loss: = 0.4
# Epoch: 702, Loss: = 0.4
# Epoch: 703, Loss: = 0.4
# Epoch: 704, Loss: = 0.4
# Epoch: 705, Loss: = 0.4
# Epoch: 706, Loss: = 0.4
# Epoch: 707, Loss: = 0.4
# Epoch: 708, Loss: = 0.4
# Epoch: 709, Loss: = 0.4
# Epoch: 710, Loss: = 0.4
# Epoch: 711, Loss: = 0.4
# Epoch: 712, Loss: = 0.4
# Epoch: 713, Loss: = 0.4
# Epoch: 714, Loss: = 0.4
# Epoch: 715, Loss: = 0.4
# Epoch: 716, Loss: = 0.4
# Epoch: 717, Loss: = 0.4
# Epoch: 718, Loss: = 0.4
# Epoch: 719, Loss: = 0.4
# Epoch: 720, Loss: = 0.4
# Epoch: 721, Loss: = 0.4
# Epoch: 722, Loss: = 0.4
# Epoch: 723, Loss: = 0.4
# Epoch: 724, Loss: = 0.4
# Epoch: 725, Loss: = 0.4
# Epoch: 726, Loss: = 0.4
# Epoch: 727, Loss: = 0.4
# Epoch: 728, Loss: = 0.4
# Epoch: 729, Loss: = 0.4
# Epoch: 730, Loss: = 0.4
# Epoch: 731, Loss: = 0.4
# Epoch: 732, Loss: = 0.4
# Epoch: 733, Loss: = 0.4
# Epoch: 734, Loss: = 0.4
# Epoch: 735, Loss: = 0.4
# Epoch: 736, Loss: = 0.4
# Epoch: 737, Loss: = 0.4
# Epoch: 738, Loss: = 0.4
# Epoch: 739, Loss: = 0.4
# Epoch: 740, Loss: = 0.4
# Epoch: 741, Loss: = 0.4
# Epoch: 742, Loss: = 0.4
# Epoch: 743, Loss: = 0.4
# Epoch: 744, Loss: = 0.4
# Epoch: 745, Loss: = 0.4
# Epoch: 746, Loss: = 0.4
# Epoch: 747, Loss: = 0.4
# Epoch: 748, Loss: = 0.4
# Epoch: 749, Loss: = 0.4
# Epoch: 750, Loss: = 0.4
# Epoch: 751, Loss: = 0.4
# Epoch: 752, Loss: = 0.4
# Epoch: 753, Loss: = 0.4
# Epoch: 754, Loss: = 0.4
# Epoch: 755, Loss: = 0.4
# Epoch: 756, Loss: = 0.4
# Epoch: 757, Loss: = 0.4
# Epoch: 758, Loss: = 0.4
# Epoch: 759, Loss: = 0.4
# Epoch: 760, Loss: = 0.4
# Epoch: 761, Loss: = 0.4
# Epoch: 762, Loss: = 0.4
# Epoch: 763, Loss: = 0.4
# Epoch: 764, Loss: = 0.4
# Epoch: 765, Loss: = 0.4
# Epoch: 766, Loss: = 0.4
# Epoch: 767, Loss: = 0.4
# Epoch: 768, Loss: = 0.4
# Epoch: 769, Loss: = 0.4
# Epoch: 770, Loss: = 0.4
# Epoch: 771, Loss: = 0.4
# Epoch: 772, Loss: = 0.4
# Epoch: 773, Loss: = 0.4
# Epoch: 774, Loss: = 0.4
# Epoch: 775, Loss: = 0.4
# Epoch: 776, Loss: = 0.4
# Epoch: 777, Loss: = 0.4
# Epoch: 778, Loss: = 0.4
# Epoch: 779, Loss: = 0.4
# Epoch: 780, Loss: = 0.4
# Epoch: 781, Loss: = 0.4
# Epoch: 782, Loss: = 0.4
# Epoch: 783, Loss: = 0.4
# Epoch: 784, Loss: = 0.4
# Epoch: 785, Loss: = 0.4
# Epoch: 786, Loss: = 0.4
# Epoch: 787, Loss: = 0.4
# Epoch: 788, Loss: = 0.4
# Epoch: 789, Loss: = 0.4
# Epoch: 790, Loss: = 0.4
# Epoch: 791, Loss: = 0.4
# Epoch: 792, Loss: = 0.4
# Epoch: 793, Loss: = 0.4
# Epoch: 794, Loss: = 0.4
# Epoch: 795, Loss: = 0.4
# Epoch: 796, Loss: = 0.4
# Epoch: 797, Loss: = 0.4
# Epoch: 798, Loss: = 0.4
# Epoch: 799, Loss: = 0.4
# Epoch: 800, Loss: = 0.4
# Epoch: 801, Loss: = 0.4
# Epoch: 802, Loss: = 0.4
# Epoch: 803, Loss: = 0.4
# Epoch: 804, Loss: = 0.4
# Epoch: 805, Loss: = 0.4
# Epoch: 806, Loss: = 0.4
# Epoch: 807, Loss: = 0.4
# Epoch: 808, Loss: = 0.4
# Epoch: 809, Loss: = 0.4
# Epoch: 810, Loss: = 0.4
# Epoch: 811, Loss: = 0.4
# Epoch: 812, Loss: = 0.4
# Epoch: 813, Loss: = 0.4
# Epoch: 814, Loss: = 0.4
# Epoch: 815, Loss: = 0.4
# Epoch: 816, Loss: = 0.4
# Epoch: 817, Loss: = 0.4
# Epoch: 818, Loss: = 0.4
# Epoch: 819, Loss: = 0.4
# Epoch: 820, Loss: = 0.4
# Epoch: 821, Loss: = 0.4
# Epoch: 822, Loss: = 0.4
# Epoch: 823, Loss: = 0.4
# Epoch: 824, Loss: = 0.4
# Epoch: 825, Loss: = 0.4
# Epoch: 826, Loss: = 0.4
# Epoch: 827, Loss: = 0.4
# Epoch: 828, Loss: = 0.4
# Epoch: 829, Loss: = 0.4
# Epoch: 830, Loss: = 0.4
# Epoch: 831, Loss: = 0.4
# Epoch: 832, Loss: = 0.4
# Epoch: 833, Loss: = 0.4
# Epoch: 834, Loss: = 0.4
# Epoch: 835, Loss: = 0.4
# Epoch: 836, Loss: = 0.4
# Epoch: 837, Loss: = 0.4
# Epoch: 838, Loss: = 0.4
# Epoch: 839, Loss: = 0.4
# Epoch: 840, Loss: = 0.4
# Epoch: 841, Loss: = 0.4
# Epoch: 842, Loss: = 0.4
# Epoch: 843, Loss: = 0.4
# Epoch: 844, Loss: = 0.4
# Epoch: 845, Loss: = 0.4
# Epoch: 846, Loss: = 0.4
# Epoch: 847, Loss: = 0.4
# Epoch: 848, Loss: = 0.3
# Epoch: 849, Loss: = 0.3
# Epoch: 850, Loss: = 0.3
# Epoch: 851, Loss: = 0.3
# Epoch: 852, Loss: = 0.3
# Epoch: 853, Loss: = 0.3
# Epoch: 854, Loss: = 0.3
# Epoch: 855, Loss: = 0.3
# Epoch: 856, Loss: = 0.3
# Epoch: 857, Loss: = 0.3
# Epoch: 858, Loss: = 0.3
# Epoch: 859, Loss: = 0.3
# Epoch: 860, Loss: = 0.3
# Epoch: 861, Loss: = 0.3
# Epoch: 862, Loss: = 0.3
# Epoch: 863, Loss: = 0.3
# Epoch: 864, Loss: = 0.3
# Epoch: 865, Loss: = 0.3
# Epoch: 866, Loss: = 0.3
# Epoch: 867, Loss: = 0.3
# Epoch: 868, Loss: = 0.3
# Epoch: 869, Loss: = 0.3
# Epoch: 870, Loss: = 0.3
# Epoch: 871, Loss: = 0.3
# Epoch: 872, Loss: = 0.3
# Epoch: 873, Loss: = 0.3
# Epoch: 874, Loss: = 0.3
# Epoch: 875, Loss: = 0.3
# Epoch: 876, Loss: = 0.3
# Epoch: 877, Loss: = 0.3
# Epoch: 878, Loss: = 0.3
# Epoch: 879, Loss: = 0.3
# Epoch: 880, Loss: = 0.3
# Epoch: 881, Loss: = 0.3
# Epoch: 882, Loss: = 0.3
# Epoch: 883, Loss: = 0.3
# Epoch: 884, Loss: = 0.3
# Epoch: 885, Loss: = 0.3
# Epoch: 886, Loss: = 0.3
# Epoch: 887, Loss: = 0.3
# Epoch: 888, Loss: = 0.3
# Epoch: 889, Loss: = 0.3
# Epoch: 890, Loss: = 0.3
# Epoch: 891, Loss: = 0.3
# Epoch: 892, Loss: = 0.3
# Epoch: 893, Loss: = 0.3
# Epoch: 894, Loss: = 0.3
# Epoch: 895, Loss: = 0.3
# Epoch: 896, Loss: = 0.3
# Epoch: 897, Loss: = 0.3
# Epoch: 898, Loss: = 0.3
# Epoch: 899, Loss: = 0.3
# Epoch: 900, Loss: = 0.3
# Epoch: 901, Loss: = 0.3
# Epoch: 902, Loss: = 0.3
# Epoch: 903, Loss: = 0.3
# Epoch: 904, Loss: = 0.3
# Epoch: 905, Loss: = 0.3
# Epoch: 906, Loss: = 0.3
# Epoch: 907, Loss: = 0.3
# Epoch: 908, Loss: = 0.3
# Epoch: 909, Loss: = 0.3
# Epoch: 910, Loss: = 0.3
# Epoch: 911, Loss: = 0.3
# Epoch: 912, Loss: = 0.3
# Epoch: 913, Loss: = 0.3
# Epoch: 914, Loss: = 0.3
# Epoch: 915, Loss: = 0.3
# Epoch: 916, Loss: = 0.3
# Epoch: 917, Loss: = 0.3
# Epoch: 918, Loss: = 0.3
# Epoch: 919, Loss: = 0.3
# Epoch: 920, Loss: = 0.3
# Epoch: 921, Loss: = 0.3
# Epoch: 922, Loss: = 0.3
# Epoch: 923, Loss: = 0.3
# Epoch: 924, Loss: = 0.3
# Epoch: 925, Loss: = 0.3
# Epoch: 926, Loss: = 0.3
# Epoch: 927, Loss: = 0.3
# Epoch: 928, Loss: = 0.3
# Epoch: 929, Loss: = 0.3
# Epoch: 930, Loss: = 0.3
# Epoch: 931, Loss: = 0.3
# Epoch: 932, Loss: = 0.3
# Epoch: 933, Loss: = 0.3
# Epoch: 934, Loss: = 0.3
# Epoch: 935, Loss: = 0.3
# Epoch: 936, Loss: = 0.3
# Epoch: 937, Loss: = 0.3
# Epoch: 938, Loss: = 0.3
# Epoch: 939, Loss: = 0.3
# Epoch: 940, Loss: = 0.3
# Epoch: 941, Loss: = 0.3
# Epoch: 942, Loss: = 0.3
# Epoch: 943, Loss: = 0.3
# Epoch: 944, Loss: = 0.3
# Epoch: 945, Loss: = 0.3
# Epoch: 946, Loss: = 0.3
# Epoch: 947, Loss: = 0.3
# Epoch: 948, Loss: = 0.3
# Epoch: 949, Loss: = 0.3
# Epoch: 950, Loss: = 0.3
# Epoch: 951, Loss: = 0.3
# Epoch: 952, Loss: = 0.3
# Epoch: 953, Loss: = 0.3
# Epoch: 954, Loss: = 0.3
# Epoch: 955, Loss: = 0.3
# Epoch: 956, Loss: = 0.3
# Epoch: 957, Loss: = 0.3
# Epoch: 958, Loss: = 0.3
# Epoch: 959, Loss: = 0.3
# Epoch: 960, Loss: = 0.3
# Epoch: 961, Loss: = 0.3
# Epoch: 962, Loss: = 0.3
# Epoch: 963, Loss: = 0.3
# Epoch: 964, Loss: = 0.3
# Epoch: 965, Loss: = 0.3
# Epoch: 966, Loss: = 0.3
# Epoch: 967, Loss: = 0.3
# Epoch: 968, Loss: = 0.3
# Epoch: 969, Loss: = 0.3
# Epoch: 970, Loss: = 0.3
# Epoch: 971, Loss: = 0.3
# Epoch: 972, Loss: = 0.3
# Epoch: 973, Loss: = 0.3
# Epoch: 974, Loss: = 0.3
# Epoch: 975, Loss: = 0.3
# Epoch: 976, Loss: = 0.3
# Epoch: 977, Loss: = 0.3
# Epoch: 978, Loss: = 0.3
# Epoch: 979, Loss: = 0.3
# Epoch: 980, Loss: = 0.3
# Epoch: 981, Loss: = 0.3
# Epoch: 982, Loss: = 0.3
# Epoch: 983, Loss: = 0.3
# Epoch: 984, Loss: = 0.3
# Epoch: 985, Loss: = 0.3
# Epoch: 986, Loss: = 0.3
# Epoch: 987, Loss: = 0.3
# Epoch: 988, Loss: = 0.3
# Epoch: 989, Loss: = 0.3
# Epoch: 990, Loss: = 0.3
# Epoch: 991, Loss: = 0.3
# Epoch: 992, Loss: = 0.3
# Epoch: 993, Loss: = 0.3
# Epoch: 994, Loss: = 0.3
# Epoch: 995, Loss: = 0.3
# Epoch: 996, Loss: = 0.3
# Epoch: 997, Loss: = 0.3
# Epoch: 998, Loss: = 0.3
# Epoch: 999, Loss: = 0.3
# Epoch: 1000, Loss: = 0.3
# Accuracy of logistic regression on test data = 91.11 percent.

# %% [markdown]
# ### Q3.  Print the classification report on the test data. The function 'classification_report' from 'sklearn.metrics' might prove useful. (10 points)

# %%
# Enter code here
print(classification_report(test_Y, test_prediction))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.89      0.80         9
#          1.0       0.97      0.92      0.94        36
#
#     accuracy                           0.91        45
#    macro avg       0.85      0.90      0.87        45
# weighted avg       0.92      0.91      0.91        45

# %% [markdown]
# ### Q4. Based on the classification report you obtain, your classifier is better in which of the following tasks? (20 points)
# 1. If it identifies a house to have a PV panel, then it has a PV panel.
# 2. If there is a PV panel, then it identifies that it has a PV panel.
#
# ## Our prediction of weather a house has a PV panel has a precission of 0.97 and a recall of 0.92. This means that it has a higher precision than recall. This means that it does task 1 better. If it identifies a house to have a PV panel, then it has a PV panel.
#
# Furthermore, complete the code below to plot the energy drawn from the grid from houses with and without PV panels.

# %%
# Plot energy drawn from grid for houses with PV's.
house_id_pv = random.sample(list(dfData_houses.loc[dfData_houses['pv'] == 1].index.values), 5)

fig, axs = plt.subplots(1, 5, sharey=True, figsize=(15,5))

for tt, house_id in enumerate(house_id_pv):
    for day in days_data:
        # Enter code here
        axs[tt].plot(energy_day(house_id,day,'grid'))
        axs[tt].set_title("House " + str(house_id))
fig.suptitle('Houses with PV panels.', fontsize=18)

for ax in axs.flat:
    ax.set(xlabel='Hour', ylabel='Energy in kWh')
for ax in axs.flat:
    ax.label_outer()

house_id_not_pv = random.sample(list(dfData_houses.loc[dfData_houses['pv'] == 0].index.values), 5)

fig, axs = plt.subplots(1, 5, sharey=True, figsize=(15,5))
axs = axs.ravel()

for tt, house_id in enumerate(house_id_not_pv):
    for day in days_data:
    # Enter code here
        axs[tt].plot(energy_day(house_id,day, 'grid'))
        axs[tt].set_title(house_id)

fig.suptitle('Houses without PV panels.', fontsize=18)        

for ax in axs.flat:
    ax.set(xlabel='Hour', ylabel='Energy in kWh')
for ax in axs.flat:
    ax.label_outer()

# %% [markdown]
# ### Q5. Design a classifier to distinguish between houses with and without PV based on the plots. Print your classification report, and compare it with logistic regression. (10 points, bonus)

# %%
# Compare the performance of a neural network based classifier with an educated guess.
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC

# %%
f=MLPClassifier(hidden_layer_sizes=(20, 10), max_iter=200)
classifier = SVC(C=1, kernel='rbf', max_iter=100000)
classifier.fit(train_X,train_Y)
lol=classifier.predict(test_X)
# Out:
# /Users/ab/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/ab/opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
print(classification_report(test_Y, lol))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.82      1.00      0.90         9
#          1.0       1.00      0.94      0.97        36
#
#     accuracy                           0.96        45
#    macro avg       0.91      0.97      0.94        45
# weighted avg       0.96      0.96      0.96        45

# %% [markdown]
# ## MLP Classifier with hidden layer sizes(20,10) did as well as the regression based neural network with accuracy around 0.91. The SVC classifier with rbf kernel did extremely well and had an accuracy of 0.96. Had 100% recall detecting no PV and 100% precision detecting if there is PV. Also, SVC classifier has f1 score 0.96 which is higher than that of the regression based neural network which has f1 scare of 0.91. Hence, SVC classifier, its the best.

# %% [markdown]
# ## What appliance consumes the most power?
#
# Thermal loads are almost always the appliances that consume the most power. The amount of power they draw also typically grows with the size of the house. In the following, we have two tasks:
# 1. What percentage of energy consumption is due to an air conditioner?
# 2. Can you derive a linear relationship between household square footage and power consumption from air conditions in July 2017?

# %%
for house_id in dfData_houses.index.values:
    dfData_houses.at[house_id, 'ac_usage'] = (total_energy_all_days(house_id, 'air1') + 
                                              total_energy_all_days(house_id, 'air2') + 
                                              total_energy_all_days(house_id, 'air3') +
                                              total_energy_all_days(house_id, 'airwindowunit1')
                                          )
    dfData_houses.at[house_id, 'total_usage'] = total_energy_all_days(house_id, 'use')

fig, axs = plt.subplots(1, 2, figsize=(15,5))

axs[0].scatter(dfData_houses['area'].values, 
               dfData_houses['ac_usage'].values, 
               c='r', marker='o', label='AC usage'
              )
axs[0].set_xlabel('Floor area of house (sq. ft.)')
axs[0].set_ylabel('Total AC Usage (kWh).')
axs[0].set_title('Power consumption from air conditioners July 2017.', fontsize=14)

axs[1].hist(x=np.divide(dfData_houses['ac_usage'], dfData_houses['total_usage']), bins=20, alpha=0.6, color='#0504aa', rwidth=0.85)
axs[1].set_xlabel('Fraction of AC usage over total power consumption')
axs[1].set_ylabel('Frequency')
axs[1].set_title('Histogram of AC usage as a fraction of total power consumption.', fontsize=14)
# Out:
# Text(0.5, 1.0, 'Histogram of AC usage as a fraction of total power consumption.')

# %% [markdown]
# ### Q6. Based on the above analysis, will you expect the total power consumption from customers to be more or less in October as compared to that in July? How does the above analysis compare to your analysis in Lab 1 on aggregate load prediction in Texas? (10 points)
#
# ## Based on the above analysis, I would expect power consumption to be more in july than october. October is a month with way more optimal temperature for us humans so we do not use the AC as frequently. Hence, Power consumption should be less. This is exactly what we saw in Lab 1.
#
# ### Q7. Can you think of a business case for the above histogram? (5 points, bonus)
#
# ## I would sell PV panels to houses with more floor area as they have huge power consumption because of their AC's. I would try to sell the fact that a considerable chunk of their electricity bill reduces and they would profit in the long run more than anyone else.

# %% [markdown]
# ### Compute monthly electric bills for each customer
#
# Your electricity bill consists of various charges. These charges depend on the utility company you pay your electricity bill to. In Champaign, IL, your distribution utility company is Ameren. In Austin, a major distribution utility company is Austin Energy. Their bill structure is discussed in the following link:
# https://austinenergy.com/ae/residential/rates/residential-electric-rates-and-line-items
#
# Calculate the monthly bill of each household.
#
# 1. For each customer, compute the total energy consumed, available in the data field "use" over the month. Use the tiered rate structure to compute the total power bill for energy consumption.
#
# 2. For customers with PV panels, compute the total energy produced by the PV panels. Assume that Ameren Energy pays 9.7 cents/kWh for such production, and subtract the amount for solar power production from the power bill.

# %%
# Define a function that computes the electricity bill according to the structure defined by Austin Energy.

def electricity_bill(consumption):
    customer_charge = 10
    power_supply_adjustment = 2.895 * consumption / 100.0
    community_benefit_charge = (0.154 + 0.124 + 0.335) * consumption / 100.0
    regulatory_charge = 1.342 * consumption / 100.0
    
    tier_rate = [2.801, 5.832, 7.814, 9.314, 10.814]    
    tier_limits = [0, 500, 1000, 1500, 2500, math.inf]
    n_tiers = 5
    
    energy_charge = 0
    
    for tier in range(n_tiers):
        consumption_tier = min(max(consumption, tier_limits[tier]), tier_limits[tier + 1]) - tier_limits[tier]
        energy_charge += consumption_tier * tier_rate[tier] / 100.0
        
    return float('%.2f'%(1.01 * (energy_charge + customer_charge + power_supply_adjustment + community_benefit_charge
                   + regulatory_charge)))

for house_id in dfData_houses.index.values:
    dfData_houses.at[house_id, 'consumption_bill'] = electricity_bill(dfData_houses.loc[house_id, 'total_usage'])
    dfData_houses.at[house_id, 'pv_savings'] = total_energy_all_days(house_id, 'gen') * 9.7 / 100.0
    dfData_houses.at[house_id, 'electricity_bill'] = dfData_houses.loc[house_id, 'consumption_bill'] 
    - dfData_houses.loc[house_id, 'pv_savings']
    
    
print("Electricity bill computed for all customers.")
# Out:
# Electricity bill computed for all customers.

# %% [markdown]
# ### What is a good indicator of electricity bill for consumption and savings from PV?
#
# Electricity consumption significantly depends on floor area of a house. The dependency is even stronger, if the house is equipped with central AC. A scatter plot of the consumption bill against floor area reveals this dependency.
#
# Monetary savings from PV panels depends on how many PV panels there are, which way they face, and how that relates to solar insolation. The number of panels installed largely depends on the roof area. The floor area of one of the floors is a good indicator.

# %%
fig, axs = plt.subplots(1, 2, figsize=(15,4))

# Plot of electricity bill for consumption against the square footage of the house.

axs[0].scatter(dfData_houses['area'].values, 
               dfData_houses['consumption_bill'].values, 
               c='r', marker='o', label='Electricity bill from consumption'
           )
axs[0].set_xlabel('Floor area of house (sq. ft.)')
axs[0].set_ylabel('Energy bill (dollars).')
axs[0].set_title('Electricity bill from power consumption over July 2017.', fontsize=14)

# Plot monetary savings from PV against the area of the first floor.

houses_without_pv = dfData_houses.loc[dfData_houses['pv'] == 0].index.values
houses_with_pv = dfData_houses.loc[dfData_houses['pv'] == 1].index.values

axs[1].scatter(dfData_houses.loc[houses_with_pv, 'area'].values, 
               dfData_houses.loc[houses_with_pv, 'pv_savings'].values, 
               c='g', marker='o', label='Savings from PV')

axs[1].set_xlabel('Area of first floor (sq. ft.)')
axs[1].set_ylabel('Monthly savings (dollars).')
axs[1].set_title('Monthly savings from PV panels over July 2017.', fontsize=14)
# Out:
# Text(0.5, 1.0, 'Monthly savings from PV panels over July 2017.')

# %% [markdown]
# ### Given the square footage of the house and the first floor, compute the electricity bill with and without PV.
#
# Perform a linear regression on electricity bill and monthly savings from PV. Use the linear fits to compute the anticipated electricity bill with and without PV. Report your anticipated percentage savings with PV.
#
# Use the data:
# 1. Square footage of entire house = 2450 sq. ft.
# 2. Square footage of first floor = 1380 sq. ft.
#
# ### Q8. Fill in the gaps below. Let's say you have $\$18,000$ to spend on a PV and get $\$2,500 $ in solar rebate . How long will it take (in years) for you to recover the initial investment?  (20 points)
#
# ## I save 78.7 dollars a month so about 936 dollars a year. My initial investment is 15500 dollars So I would take 15500/936 which is about 16.5 years to recover my investment.

# %%
area_house = 2450
area_first_floor = 1380

XX = dfData_houses['area'].values.reshape(-1, 1) 
YY = dfData_houses['consumption_bill'].values.reshape(-1, 1)

model_consumption = linear_model.LinearRegression()
model_consumption.fit(XX, YY)

del XX, YY
print("Predicted power bill = $%.2f" %  model_consumption.predict(np.array([area_house]).reshape(-1, 1)))

# Enter code here to compute predicted savings from PV 
dfhouse_pv=dfData_houses[dfData_houses['pv'] == 1]

Xx = dfhouse_pv['area'].values.reshape(-1, 1) 

Yy = dfhouse_pv['pv_savings'].values.reshape(-1, 1)
model_savings = linear_model.LinearRegression()
model_savings.fit(Xx, Yy)
saving=model_savings.predict(np.array([area_house]).reshape(-1, 1))
del Xx, Yy
print("Predicted power savings because of PV = $%.2f" %  saving)

invest=18000-2500
yearsave=int(saving)*12
time=invest/yearsave
print(yearsave)
print("Years to recover investment of PV panels = ",time)
# Out:
# Predicted power bill = $221.84
# Predicted power savings because of PV = $78.69
# 936
# Years to recover investment of PV panels =  16.55982905982906
